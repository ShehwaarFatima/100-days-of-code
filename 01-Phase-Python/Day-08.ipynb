# %% [markdown]
# <a href="https://colab.research.google.com/github/ShehwaarFatima/100-days-of-code/blob/main/01-Phase-Python/Day-08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = [1, 2, 3]
print(a)

b = ["apple", "banana"]
print(b)
# Out:
# [1, 2, 3]
# ['apple', 'banana']

# %%
a = list((1, 2, 3, 'apple', 4.5))
print(a)

b = list("GFG")
print(b)
# Out:
# [1, 2, 3, 'apple', 4.5]
# ['G', 'F', 'G']

# %%
a = list((1, 2, 3, 'apple', 4.5))
print(a)

b = list("GFG")
print(b)
# Out:
# [1, 2, 3, 'apple', 4.5]
# ['G', 'F', 'G']

# %%
a = [2] * 5
b = [0] * 7

print(a)
print(b)
# Out:
# [2, 2, 2, 2, 2]
# [0, 0, 0, 0, 0, 0, 0]

# %%
a = [1, 2, 2, "Python"]
print(a[0])   # index-based
print(a)
# Out:
# 1
# [1, 2, 2, 'Python']
