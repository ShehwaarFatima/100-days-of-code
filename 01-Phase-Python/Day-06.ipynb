# %% [markdown]
# <a href="https://colab.research.google.com/github/ShehwaarFatima/100-days-of-code/blob/main/01-Phase-Python/Day-06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def student(fname, lname):
    print(fname, lname)

student(fname='Geeks', lname='Practice')
student(lname='Practice', fname='Geeks')
# Out:
# Geeks Practice
# Geeks Practice

# %%
def nameAge(name, age):
    print("Hi, I am", name)
    print("My age is ", age)

print("Case-1:")
nameAge("Olivia", 27)

print("Case-2:")
nameAge(27, "Olivia")
# Out:
# Case-1:
# Hi, I am Olivia
# My age is  27
# Case-2:
# Hi, I am 27
# My age is  Olivia

# %%
def f1():
    s = 'I love MyCountry'
    def f2():
        print(s)

    f2()
f1()
# Out:
# I love MyCountry

# %%
def sq_value(num):
    return num**2

print(sq_value(2))
print(sq_value(-4))
# Out:
# 4
# 16

# %%
def myFun(x):
    x[0] = 20

b = [10, 11, 12, 13]
myFun(b)
print(b)

def myFun2(x):
    x = 20

a = 10
myFun2(a)
print(a)
# Out:
# [20, 11, 12, 13]
# 10
