# %% [markdown]
# <a href="https://colab.research.google.com/github/ShehwaarFatima/100-days-of-code/blob/main/01-Phase-Python/Day-09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = [10, 20, 30]
print(a[0])
print(a[-1])
# Out:
# 10
# 30

# %%
a = [1, 2]
a.append(3)
print(a)
# Out:
# [1, 2, 3]

# %%
a = [1, 3]
a.insert(1, 2)
print(a)
# Out:
# [1, 2, 3]

# %%
a = [1, 2]
a.extend([3, 4])
print(a)
# Out:
# [1, 2, 3, 4]

# %%
a = [10, 20, 30, 40, 50]
a[1] = 25
print(a)
# Out:
# [10, 25, 30, 40, 50]

# %%
a = [1, 2, 3]
a.remove(2)
print(a)
# Out:
# [1, 3]

# %%
a = [1, 2, 3]
a.pop()
print(a)
# Out:
# [1, 2]

# %%
a = [1, 2, 3]
del a[1]
print(a)
# Out:
# [1, 3]

# %%
a = [1, 2, 3]
a.clear()
print(a)
# Out:
# []
