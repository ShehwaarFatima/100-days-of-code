# %% [markdown]
# <a href="https://colab.research.google.com/github/ShehwaarFatima/100-days-of-code/blob/main/01-Phase-Python/Day-01/Day01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# input() se data lena aur print() se show karna
name = input("Enter your name: ")
print("Hello, " + name + "!")

# %%
# Yeh Single-line Comment hai

"""
Yeh Multi-line Comment hai.
Aap isme multiple lines likh sakte hain.
"""

# %%
age = 20          # age ek variable hai
name = "Ali"      # name ek variable hai

# %%
x = 10         # int
y = 3.14       # float
z = "Python"   # str
is_active = True # bool

# %%
num_str = "100"          # String
num_int = int(num_str)   # String se Integer me convert kiya

price = 50               # Integer
price_float = float(price) # Integer se Float me convert kiya (50.0)

print(type(num_int))     # Output: <class 'int'>

# %%
a = 10
b = 3

print(a + b)   # Addition (13)
print(a - b)   # Subtraction (7)
print(a * b)   # Multiplication (30)
print(a / b)   # Division (3.333...)
print(a // b)  # Floor Division (3)
print(a % b)   # Modulus / Remainder (1)
print(a ** b)  # Exponentiation / Power (1000)

# %%
x = 10
y = 20

print(x == y)  # Equal to (False)
print(x != y)  # Not Equal to (True)
print(x > y)   # Greater than (False)
print(x < y)   # Less than (True)
print(x >= 10) # Greater than or equal to (True)
print(y <= 15) # Less than or equal to (False)
# Out:
# False
# True
# False
# True
# True
# False

# %%
x = 10      # Simple Assignment

x += 5      # Same as: x = x + 5
print(f"{x}")
x -= 3      # Same as: x = x - 3
print(f"{x}")
x *= 2      # Same as: x = x * 2
print(f"{x}")
x /= 4      # Same as: x = x / 4
print(f"{x}")
# Out:
# 15
# 12
# 24
# 6.0
